# %% [markdown]
# <h1 align="center">MOM6/OM4 mass transports through straits and throughflows</h1>
#
# This notebook provides example calculations of the mass transport through various sections saved from OM4 simulations.
#
# This iPython notebook was originally developed at NOAA/GFDL, and it is provided freely to the MOM6 community. GFDL scientists developing MOM6 make extensive use of Python for diagnostics. We solicit modifications/fixes that are useful to the MOM6 community.

# %%
# %pylab inline
import matplotlib.pyplot as plt
import netCDF4

# data layout for a section is (t,z,y,x)

# %%
mks2Sv = 1.0/1e9

# %%
path = './'
Agulhas = netCDF4.Dataset(path+'19000101.rregionocean_Agulhas_section.nc.0096')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Agulhas.variables: print v,

time           = Agulhas.variables['time'][:]
trans          = Agulhas.variables['umo'][:]
transA         = trans.sum(axis=1)
trans_Agulhas  = mks2Sv*transA.sum(axis=1) 
print '' 
print ''
print time.shape 
print trans.shape
print trans_Agulhas.shape
print trans_Agulhas
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub02 zl time nv xq_sub01 yh_sub01 zi thetao so umo uo e average_T1 average_T2 average_DT time_bounds
#
# (6,)
# (6, 75, 60, 1)
# (6, 1)
# [[  7.92169666]
#  [  2.48300314]
#  [-21.93109131]
#  [-49.22773743]
#  [-48.2850647 ]
#  [-48.24036026]]

# %%
path = './'
Barents = netCDF4.Dataset(path+'19000101.rregionocean_Barents_opening.nc.0417')

# need to save umo not vmo 

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Barents.variables: print v,

trans          = Barents.variables['umo'][:]
transA         = trans.sum(axis=1)
trans_Barents  = mks2Sv*transA.sum(axis=1) 
print '' 
print ''
print time.shape 
print trans.shape
print trans_Barents.shape
print trans_Barents
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub02 zl time nv xq_sub01 yh_sub01 zi theta so umo uo e average_T1 average_T2 average_DT time_bounds
#
# (6,)
# (6, 75, 60, 1)
# (6, 1)
# [[ 5.06636524]
#  [ 2.30437899]
#  [-2.98418331]
#  [-1.91340709]
#  [-0.13564186]
#  [-0.36029509]]

# %%
path = './'
Canada = netCDF4.Dataset(path+'19000101.rregionocean_Canadian_Archipelago.nc.0386')

# need to save umo not vmo 

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Canada.variables: print v,
    
trans          = Canada.variables['vmo'][:]
transA         = trans.sum(axis=1)
trans_Canada  = mks2Sv*transA.sum(axis=2) 
print '' 
print ''
print time.shape 
print trans.shape
print trans_Canada.shape
print trans_Canada
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub01 zl time nv yq_sub01 zi theta so vmo vo e average_T1 average_T2 average_DT time_bounds
#
# (6,)
# (6, 75, 1, 45)
# (6, 1)
# [[-0.18738681078]
#  [-0.661976218224]
#  [0.893458664417]
#  [3.07564425468]
#  [3.30177736282]
#  [-0.728756606579]]

# %%
path = './'
Denmark = netCDF4.Dataset(path+'19000101.rregionocean_Denmark_Strait.nc.0389')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Denmark.variables: print v,

trans         = Denmark.variables['vmo'][:]
transA        = trans.sum(axis=1)
trans_Denmark = mks2Sv*transA.sum(axis=2) 
print '' 
print ''
print trans.shape
print trans_Denmark.shape
print trans_Denmark
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub01 zl time nv yq_sub01 zi thetao so vmo vo e average_T1 average_T2 average_DT time_bounds
#
# (6, 75, 1, 38)
# (6, 1)
# [[-0.256385505199]
#  [-0.643898785114]
#  [-1.88431620598]
#  [-3.63401317596]
#  [-1.94770812988]
#  [0.388997256756]]

# %%
path = './'
Drake  = netCDF4.Dataset(path+'19000101.rregionocean_Drake_Passage.nc.0056')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Drake.variables: print v,

trans        = Drake.variables['umo'][:]
transA       = trans.sum(axis=1)
trans_Drake  = mks2Sv*transA.sum(axis=1) 
print '' 
print ''
print time.shape 
print trans.shape
print trans_Drake.shape
print trans_Drake
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub02 zl time nv xq_sub01 yh_sub01 zi thetao so umo uo e average_T1 average_T2 average_DT time_bounds
#
# (6,)
# (6, 75, 60, 1)
# (6, 1)
# [[-7.36340284348]
#  [-16.6699314117]
#  [-25.9028377533]
#  [-28.1649608612]
#  [-36.4449043274]
#  [-54.6206321716]]

# %%
path = './'
English = netCDF4.Dataset(path+'19000101.rregionocean_English_Channel.nc.0353')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in English.variables: print v,

trans        = English.variables['umo'][:]
transA       = trans.sum(axis=1)
trans_English  = mks2Sv*transA.sum(axis=1) 
print '' 
print ''
print time.shape 
print trans.shape
print trans_English.shape
print trans_English
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub02 zl time nv xq_sub01 yh_sub01 zi thetao so umo uo e average_T1 average_T2 average_DT time_bounds
#
# (6,)
# (6, 75, 3, 1)
# (6, 1)
# [[0.000842561887112]
#  [-0.0049596647732]
#  [-0.0153185836971]
#  [-0.0131565071642]
#  [-0.0097789671272]
#  [-0.015196941793]]

# %%
path = './'
Faroe_Scot = netCDF4.Dataset(path+'19000101.rregionocean_Faroe_Scotland.nc.0373')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Faroe_Scot.variables: print v,

trans        = Faroe_Scot.variables['umo'][:]
transA       = trans.sum(axis=1)
trans_Faroe_Scot  = mks2Sv*transA.sum(axis=1) 
print '' 
print ''
print trans.shape
print trans_Faroe_Scot.shape
print trans_Faroe_Scot
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub02 yh_sub02 zl time nv xq_sub01 yh_sub01 zi thetao so umo uo e average_T1 average_T2 average_DT time_bounds
#
# (6, 75, 33, 1)
# (6, 1)
# [[-0.528902411461]
#  [-1.91713881493]
#  [-3.29412221909]
#  [-5.26007509232]
#  [-11.0922317505]
#  [-15.5970363617]]

# %%
path = './'
Florida = netCDF4.Dataset(path+'19000101.rregionocean_Florida_Bahamas.nc.0299')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Florida.variables: print v,

trans        = Florida.variables['vmo'][:]
transA       = trans.sum(axis=1)
trans_Florida  = mks2Sv*transA.sum(axis=2) 
print '' 
print ''
print trans.shape
print trans_Florida.shape
print trans_Florida
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub01 zl time nv yq_sub01 zi thetao so vmo vo e average_T1 average_T2 average_DT time_bounds
#
# (6, 75, 1, 12)
# (6, 1)
# [[-0.0931820645928]
#  [-0.13677278161]
#  [-0.2401881814]
#  [-1.49632930756]
#  [-4.00168943405]
#  [-4.93576478958]]

# %%
path = './'
Fram = netCDF4.Dataset(path+'19000101.rregionocean_Fram_Strait.nc.0444')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Fram.variables: print v,

trans        = Fram.variables['vmo'][:]
transA       = trans.sum(axis=1)
trans_Fram   = mks2Sv*transA.sum(axis=2) 
print '' 
print ''
print trans.shape
print trans_Fram.shape
print trans_Fram
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub01 zl time nv yq_sub01 zi thetao so vmo vo e average_T1 average_T2 average_DT time_bounds
#
# (6, 75, 1, 45)
# (6, 1)
# [[  2.17269826]
#  [  7.07976341]
#  [ 12.27072811]
#  [ 14.90528965]
#  [ 18.33521461]
#  [ 19.22170258]]

# %%
path = './'
Gibraltar = netCDF4.Dataset(path+'19000101.rregionocean_Gibraltar_Strait.nc.0306')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Gibraltar.variables: print v,

trans        = Gibraltar.variables['umo'][:]
transA       = trans.sum(axis=1)
trans_Gibraltar   = mks2Sv*transA.sum(axis=1) 
print '' 
print ''
print trans.shape
print trans_Gibraltar.shape
print trans_Gibraltar
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub02 zl time nv xq_sub01 yh_sub01 zi thetao so umo uo e average_T1 average_T2 average_DT time_bounds
#
# (6, 75, 3, 1)
# (6, 1)
# [[-0.10023123771]
#  [-0.522965192795]
#  [-0.931773662567]
#  [-1.47121036053]
#  [-1.893902421]
#  [-2.18514943123]]

# %%
path = './'
Iceland_Faroe_U = netCDF4.Dataset(path+'19000101.rregionocean_Iceland_Faroe_U.nc.0372')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Iceland_Faroe_U.variables: print v,

transU     = Iceland_Faroe_U.variables['umo'][:]
transA     = transU.sum(axis=1)
trans_Iceland_Faroe_U = mks2Sv*transA.sum(axis=1) 


path = './'
Iceland_Faroe_V = netCDF4.Dataset(path+'19000101.rregionocean_Iceland_Faroe_V.nc.0372')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Iceland_Faroe_V.variables: print v,

transV     = Iceland_Faroe_V.variables['vmo'][:]
transA     = transV.sum(axis=1)
trans_Iceland_Faroe_V = mks2Sv*transA.sum(axis=2) 

trans_Iceland_Faroe = trans_Iceland_Faroe_U + trans_Iceland_Faroe_V

print '' 
print ''
print trans_Iceland_Faroe_U.shape
print trans_Iceland_Faroe_V.shape
print trans_Iceland_Faroe.shape
print trans_Iceland_Faroe
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub02 yh_sub03 zl time nv xq_sub01 yh_sub01 zi thetao so umo uo e average_T1 average_T2 average_DT time_bounds
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub02 zl time nv yq_sub01 zi thetao so vmo vo e average_T1 average_T2 average_DT time_bounds
#
# (6, 1)
# (6, 1)
# (6, 1)
# [[-2.11994099617]
#  [-2.82666778564]
#  [-5.60508203506]
#  [-10.6419868469]
#  [-14.5572414398]
#  [-17.6307849884]]

# %%
path = './'
Iceland_Norway = netCDF4.Dataset(path+'19000101.rregionocean_Iceland_Norway.nc.0389')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Iceland_Norway.variables: print v,

trans        = Iceland_Norway.variables['vmo'][:]
transA       = trans.sum(axis=1)
trans_Iceland_Norway = mks2Sv*transA.sum(axis=2) 
print '' 
print ''
print trans.shape
print trans_Iceland_Norway.shape
print trans_Iceland_Norway
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub02 yh_sub02 zl time nv yq_sub02 zi thetao so vmo vo e average_T1 average_T2 average_DT time_bounds
#
# (6, 75, 1, 8)
# (6, 1)
# [[--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]]

# %%
path = './'
Indo = netCDF4.Dataset(path+'19000101.rregionocean_Indonesian_Throughflow.nc.0200')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Indo.variables: print v,

trans        = Indo.variables['vmo'][:]
transA       = trans.sum(axis=1)
trans_Indo = mks2Sv*transA.sum(axis=2) 
print '' 
print ''
print trans.shape
print trans_Indo.shape
print trans_Indo
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub01 zl time nv yq_sub01 zi thetao so vmo vo e average_T1 average_T2 average_DT time_bounds
#
# (6, 75, 1, 8)
# (6, 1)
# [[0.0450794845819]
#  [0.132039368153]
#  [0.365629583597]
#  [0.716331839561]
#  [1.20567321777]
#  [1.4479995966]]

# %%
path = './'
Moz = netCDF4.Dataset(path+'19000101.rregionocean_Mozambique_Channel.nc.0223')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Moz.variables: print v,

trans        = Moz.variables['vmo'][:]
transA       = trans.sum(axis=1)
trans_Moz = mks2Sv*transA.sum(axis=2) 
print '' 
print ''
print trans.shape
print trans_Moz.shape
print trans_Moz
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub01 zl time nv yq_sub01 zi thetao so vmo vo e average_T1 average_T2 average_DT time_bounds
#
# (6, 75, 1, 29)
# (6, 1)
# [[0.320901930332]
#  [-5.29505872726]
#  [-14.472492218]
#  [-12.7704391479]
#  [4.81719398499]
#  [41.5789527893]]

# %%
path = './'
PEUC = netCDF4.Dataset(path+'19000101.rregionocean_Pacific_undercurrent.nc.0237')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in PEUC.variables: print v,

trans        = PEUC.variables['umo'][:]
transA       = trans.sum(axis=1)
trans_PEUC = mks2Sv*transA.sum(axis=1) 
print '' 
print ''
print trans.shape
print trans_PEUC.shape
print trans_PEUC
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub01 zl time nv xq_sub01 zi thetao so umo uo e average_T1 average_T2 average_DT time_bounds
#
# (6, 75, 1, 1)
# (6, 1)
# [[-0.07784339]
#  [-0.32963336]
#  [-0.48796126]
#  [-0.597826  ]
#  [-0.6174773 ]
#  [-0.84622169]]

# %%
path = './'
Taiwan = netCDF4.Dataset(path+'19000101.rregionocean_Taiwan_Luzon.nc.0260')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Taiwan.variables: print v,

trans        = Taiwan.variables['umo'][:]
transA       = trans.sum(axis=1)
trans_Taiwan = mks2Sv*transA.sum(axis=1) 
print '' 
print ''
print trans.shape
print trans_Taiwan.shape
print trans_Taiwan
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub01 yh_sub02 zl time nv xq_sub01 yh_sub01 zi thetao so umo uo e average_T1 average_T2 average_DT time_bounds
#
# (6, 75, 27, 1)
# (6, 1)
# [[8.16555690765]
#  [10.8567047119]
#  [3.42283153534]
#  [-0.985945641994]
#  [-7.6505074501]
#  [-24.0470485687]]

# %%
path = './'
Windward = netCDF4.Dataset(path+'19000101.rregionocean_Windward_Passage.nc.0275')

print ' '     
print 'VARIABLES IN MAIN FILE'
for v in Windward.variables: print v,

trans        = Windward.variables['vmo'][:]
transA       = trans.sum(axis=1)
trans_Windward = mks2Sv*transA.sum(axis=2) 
print '' 
print ''
print trans.shape
print trans_Windward.shape
print trans_Windward
# Out:
#
# VARIABLES IN MAIN FILE
# xh_sub02 yh_sub01 zl time nv xh_sub01 yq_sub01 zi theta so vmo vo e average_T1 average_T2 average_DT time_bounds
#
# (6, 75, 1, 9)
# (6, 1)
# [[-0.759822309017]
#  [-1.45327067375]
#  [-1.02644729614]
#  [-9.89729309082]
#  [-15.2821788788]
#  [-16.3439331055]]

# %%
# for easy setup of subplots
def newSP(y,x):
    global __spv, __spi ; __spv = (y,x) ; __spi = 1 ; plt.subplot(__spv[0], __spv[1], __spi)
def nextSP():
    global __spv, __spi ; __spi = __spi + 1 ; plt.subplot(__spv[0], __spv[1], __spi)

# %%
figure(figsize=(16,12))
newSP(3,3)

plt.subplot(331);
plt.plot(time, trans_Agulhas);
plt.title(r'Agulhas',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(332);
plt.plot(time, trans_Barents);
plt.title(r'Barents Opening',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(333);
plt.plot(time, trans_Canada);
plt.title(r'Canadian Archepelago',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(334);
plt.plot(time, trans_Denmark);
plt.title(r'Denmark Strait',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(335);
plt.plot(time, trans_Drake);
plt.title(r'Drake Passage',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(336);
plt.plot(time, trans_English);
plt.title(r'English Channel',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(337);
plt.plot(time, trans_Faroe_Scot);
plt.title(r'Faroe-Scotland',fontsize=18)
plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(338);
plt.plot(time, trans_Florida);
plt.title(r'Florida-Bahamas',fontsize=18)
plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(339);
plt.plot(time, trans_Fram);
plt.title(r'Fram Strait',fontsize=18)
plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

# %%
figure(figsize=(16,12))
newSP(3,3)

plt.subplot(331);
plt.plot(time, trans_Gibraltar);
plt.title(r'Gibraltar Strait',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(332);
plt.plot(time, trans_Iceland_Faroe);
plt.title(r'Iceland-Faroe',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(333);
plt.plot(time, trans_Iceland_Norway);
plt.title(r'Iceland-Norway',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(334);
plt.plot(time, trans_Indo);
plt.title(r'Indonesian Throughflow',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(335);
plt.plot(time, trans_Moz);
plt.title(r'Mozambique Channel',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(336);
plt.plot(time, trans_PEUC);
plt.title(r'Pacific Equatorial Undercurrent',fontsize=18)
#plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(337);
plt.plot(time, trans_Taiwan);
plt.title(r'Taiwan-Luzon Strait',fontsize=18)
plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);

plt.subplot(338);
plt.plot(time, trans_Windward);
plt.title(r'Windward Passage',fontsize=18)
plt.xlabel('Time (days)',fontsize=18)
plt.ylabel('Transport (Sv)',fontsize=18);
